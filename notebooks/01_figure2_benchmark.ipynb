# %% [markdown]
# # Figure 2 frozen-evidence walkthrough
#
# This lightweight notebook inspects compact frozen summaries behind the present-state reconstruction benchmark. It does **not** fit AtlasTailor, recompute metrics, or reproduce the final manual Inkscape layout.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd()
if not (root / 'examples').is_dir():
    root = root.parent
evidence = root / 'examples' / 'manuscript_evidence' / 'figure_02'
assert evidence.is_dir(), 'Run from the repository root or notebooks/'
primary = pd.read_csv(evidence / 'PRIMARY_ENDPOINTS_BY_EMBRYO.tsv', sep='\t')
comparisons = pd.read_csv(evidence / 'METHOD_COMPARISONS_BY_EMBRYO.tsv', sep='\t')
transimpspa = pd.read_csv(evidence / 'TRANSIMPSPA_FIGURE_METRICS.tsv', sep='\t')

# %% [markdown]
# ## Reciprocal reconstruction endpoints

# %%
primary.head()

# %% [markdown]
# ## External method comparisons
#
# These rows preserve the frozen comparison universe. Inspect column names before choosing a manuscript-specific view.

# %%
comparisons.head(), transimpspa.head()

# %% [markdown]
# ## Reproducibility boundary
#
# The companion `AtlasTailor-reproducibility` repository provides the complete frozen tables, executed workflows, source-panel SVGs, configurations, prediction-lock provenance, and checksums.
